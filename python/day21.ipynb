# %%
import pandas as pd

# %%
marks = pd.Series([10, 20, 25, 32, 44, 21, 25], )

print(marks.head(3))
print(marks.tail(2))
print(marks.sum())
print(marks.mean())
print(marks.max())
print(marks.min())
print(marks.sort_values())
print(marks.unique())
print(marks.nunique())
print(marks.apply(lambda x : x<30))
# Out:
# 0    10
# 1    20
# 2    25
# dtype: int64
# 5    21
# 6    25
# dtype: int64
# 177
# 25.285714285714285
# 44
# 10
# 0    10
# 1    20
# 5    21
# 2    25
# 6    25
# 3    32
# 4    44
# dtype: int64
# [10 20 25 32 44 21]
# 6
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
dic = [
    {"Aniket" , 86},
    {"Suraj" , 45}
] 

df = pd.DataFrame(dic, columns = ["Name", "Marks"])
print(df)
# Out:
#      Name  Marks
# 0  Aniket     86
# 1   Suraj     45

# %%
rows = [['Adi' , 21], ['Rishi', 19]]

df1 = pd.DataFrame(rows, columns=['Name', 'Age'])

print(df1)
# Out:
#     Name  Age
# 0    Adi   21
# 1  Rishi   19

# %%
# df_csv = pd.read_csv('students.csv')
# df_xls = pd.read_excel('students.xlsx', sheet_name = 'Sheet 1')
# df_json = pd.read_json('students.json')

# %%
print(df.sample(1))
# Out:
#      Name  Marks
# 0  Aniket     86

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Marks   2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes
# None

# %%
print(df.describe())
# Out:
#            Marks
# count   2.000000
# mean   65.500000
# std    28.991378
# min    45.000000
# 25%    55.250000
# 50%    65.500000
# 75%    75.750000
# max    86.000000

# %%
print(df.shape)
# Out:
# (2, 2)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
print(df.dtypes)
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
print(df['Name'].value_counts())
# Out:
# Name
# Aniket    1
# Suraj     1
# Name: count, dtype: int64

# %%
print(df['Marks'].unique())
# Out:
# [86 45]

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# dtype: bool

# %%
df.drop_duplicates(subset=['Name'], keep='first')
# Out:
#      Name  Marks
# 0  Aniket     86
# 1   Suraj     45
