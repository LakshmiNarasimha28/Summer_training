# %%
import pandas as pd

# %%
df_csv = pd.read_csv("C:/Users/mrpro//Downloads/students_clean.csv")

# %%
df_csv.sample(10)
# Out:
#     StudentID    Name Gender     City    JoinDate  Math  Science  English
# 32         33   Swati      M     Pune  2024-10-24  70.0     93.0     73.0
# 36         37  Bhavya      F   Mumbai  2024-11-29  37.0     43.0     64.9
# 26         27  Simran      M  Kolkata  2024-08-31  84.0     37.0     45.0
# 9          10   Rahul      M  Chennai  2024-03-31  88.0     75.0     36.0
# 31         32   Rajat      M    Delhi  2024-10-15  84.0     53.0     75.0
# 16         17   Pooja      F     Pune  2024-06-02  50.0     73.0     80.0
# 11         12   Kabir      F    Delhi  2024-04-18  86.0     70.0     40.0
# 3           4   Karan      M   Mumbai  2024-02-06  66.6     65.0     61.0
# 10         11   Divya      F  Chennai  2024-04-09  62.0     71.0     41.0
# 15         16    Aman      F    Delhi  2024-05-24  53.0     54.0     64.0

# %%
df_csv.dropna()
# Out:
#     StudentID       Name Gender     City    JoinDate  Math  Science  English
# 0           1      Aditi      M    Delhi  2024-01-10  95.0     63.0     98.0
# 1           2      Rohan      F  Chennai  2024-01-19  62.0     77.0     77.0
# 2           3      Meera      F  Chennai  2024-01-28  45.0     76.0     61.0
# 3           4      Karan      M   Mumbai  2024-02-06  66.6     65.0     61.0
# 4           5      Sneha      M    Delhi  2024-02-15  75.0     89.0     61.0
# 5           6      Arjun      F  Kolkata  2024-02-24  79.0     71.0     87.0
# 6           7      Priya      M     Pune  2024-03-04  41.0     40.0     55.0
# 7           8     Vikram      F  Kolkata  2024-03-13  54.0     83.0     45.0
# 8           9     Anjali      M  Chennai  2024-03-22  84.0     66.2     56.0
# 9          10      Rahul      M  Chennai  2024-03-31  88.0     75.0     36.0
# 10         11      Divya      F  Chennai  2024-04-09  62.0     71.0     41.0
# ...

# %%
df_csv.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
df_csv.drop_duplicates()
# Out:
#     StudentID       Name Gender     City    JoinDate  Math  Science  English
# 0           1      Aditi      M    Delhi  2024-01-10  95.0     63.0     98.0
# 1           2      Rohan      F  Chennai  2024-01-19  62.0     77.0     77.0
# 2           3      Meera      F  Chennai  2024-01-28  45.0     76.0     61.0
# 3           4      Karan      M   Mumbai  2024-02-06  66.6     65.0     61.0
# 4           5      Sneha      M    Delhi  2024-02-15  75.0     89.0     61.0
# 5           6      Arjun      F  Kolkata  2024-02-24  79.0     71.0     87.0
# 6           7      Priya      M     Pune  2024-03-04  41.0     40.0     55.0
# 7           8     Vikram      F  Kolkata  2024-03-13  54.0     83.0     45.0
# 8           9     Anjali      M  Chennai  2024-03-22  84.0     66.2     56.0
# 9          10      Rahul      M  Chennai  2024-03-31  88.0     75.0     36.0
# 10         11      Divya      F  Chennai  2024-04-09  62.0     71.0     41.0
# ...

# %%
ip = input('Enter Name of Student ')

df_csv[df_csv['Name'] == ip]
# Out:
# Enter Name of Student  Om
#     StudentID Name Gender     City    JoinDate  Math  Science  English
# 39         40   Om      F  Chennai  2024-12-26  42.0     85.0     96.0

# %%
subjects = ["Math", "Science", "English"]
df_csv['Math'].describe()
# Out:
# count    40.000000
# mean     66.570000
# std      17.478987
# min      35.000000
# 25%      51.500000
# 50%      66.600000
# 75%      84.000000
# max      95.000000
# Name: Math, dtype: float64

# %%
df_csv['English'].describe()
# Out:
# count    40.000000
# mean     64.942500
# std      17.551315
# min      36.000000
# 25%      53.000000
# 50%      64.450000
# 75%      78.250000
# max      98.000000
# Name: English, dtype: float64

# %%
df_csv['Science'].describe()
# Out:
# count    40.00000
# mean     66.21000
# std      17.27479
# min      36.00000
# 25%      53.00000
# 50%      66.60000
# 75%      77.00000
# max      98.00000
# Name: Science, dtype: float64

# %%
print(df_csv.groupby('City')['Math'].mean().round())
# Out:
# City
# Chennai    60.64
# Delhi      73.58
# Kolkata    68.00
# Mumbai     68.94
# Pune       64.96
# Name: Math, dtype: float64

# %%
df_csv["Total"] = df_csv[subjects].sum(axis=1)

df_csv["Average"] = df_csv[subjects].mean(axis=1).round(2)

df_csv["Rank"] = df_csv["Total"].rank(method="min", ascending=False).astype(int)

df_csv
# Out:
#     StudentID       Name Gender     City    JoinDate  Math  Science  English  \
# 0           1      Aditi      M    Delhi  2024-01-10  95.0     63.0     98.0
# 1           2      Rohan      F  Chennai  2024-01-19  62.0     77.0     77.0
# 2           3      Meera      F  Chennai  2024-01-28  45.0     76.0     61.0
# 3           4      Karan      M   Mumbai  2024-02-06  66.6     65.0     61.0
# 4           5      Sneha      M    Delhi  2024-02-15  75.0     89.0     61.0
# 5           6      Arjun      F  Kolkata  2024-02-24  79.0     71.0     87.0
# 6           7      Priya      M     Pune  2024-03-04  41.0     40.0     55.0
# 7           8     Vikram      F  Kolkata  2024-03-13  54.0     83.0     45.0
# 8           9     Anjali      M  Chennai  2024-03-22  84.0     66.2     56.0
# 9          10      Rahul      M  Chennai  2024-03-31  88.0     75.0     36.0
# 10         11      Divya      F  Chennai  2024-04-09  62.0     71.0     41.0
# ...

# %%
df_csv['P/F'] = df_csv.apply(lambda row: 'Pass' if row['Total'] > 150 else 'Fail', axis=1)

df_csv
# Out:
#     StudentID       Name Gender     City    JoinDate  Math  Science  English  \
# 0           1      Aditi      M    Delhi  2024-01-10  95.0     63.0     98.0
# 1           2      Rohan      F  Chennai  2024-01-19  62.0     77.0     77.0
# 2           3      Meera      F  Chennai  2024-01-28  45.0     76.0     61.0
# 3           4      Karan      M   Mumbai  2024-02-06  66.6     65.0     61.0
# 4           5      Sneha      M    Delhi  2024-02-15  75.0     89.0     61.0
# 5           6      Arjun      F  Kolkata  2024-02-24  79.0     71.0     87.0
# 6           7      Priya      M     Pune  2024-03-04  41.0     40.0     55.0
# 7           8     Vikram      F  Kolkata  2024-03-13  54.0     83.0     45.0
# 8           9     Anjali      M  Chennai  2024-03-22  84.0     66.2     56.0
# 9          10      Rahul      M  Chennai  2024-03-31  88.0     75.0     36.0
# 10         11      Divya      F  Chennai  2024-04-09  62.0     71.0     41.0
# ...
